# %%
import pandas as pd
import numpy as np
import matplotlib as mpl


l = np.arange(10)
arr = np.random.rand(len(l),2)
df = pd.DataFrame(arr, columns=['a','b']).reset_index()

df.plot(x='a', y='b', kind='scatter')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
